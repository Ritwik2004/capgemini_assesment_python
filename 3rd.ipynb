# %%
# i = 1
# while i<=100:
#     s = str(i)
#     if '7' in s:
#         print(i)
#     i += 1


i = 1
while i <= 100:
    n = i
    found_seven = False
    while n > 0:
        if n % 10 == 7:
            found_seven = True
            break
        n //= 10
    if found_seven:
        print(i)
    i += 1
# Out:
# 7
# 17
# 27
# 37
# 47
# 57
# 67
# 70
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 79
# 87
# 97

# %%
num = eval(input("Enter the number : "))
cnum = num
revNum = 0
while num>0:
    rem = num%10
    revNum = revNum *10 +rem
    num = num//10
print("The reverse number is : ",revNum)
if cnum<revNum:
    print("the reverse number is greater than the original number...")
# Out:
# The reverse number is :  123

# %%
num = eval(input("Enter a number : "))
sumdig = num
leng = len(str(num))
while leng>1:
    num = sumdig
    sumdig = 0
    while num>0:
        rem = num%10
        sumdig+=rem
        num=num//10
    leng = len(str(sumdig))
    # print("length : ", leng)
print("The sum is : ",sumdig)
#4695
# Out:
# The sum is :  6

# %%
num = eval(input("Enter a number : "))
even = 0
odd = 0
while num>0:
    rem = num%10
    if rem%2 == 0:
        even += 1
    else:
        odd += 1
    num = num//10
print("The number of even digits is : ",even)
print("and the number of odd digits is : ",odd)
# Out:
# The number of even digits is :  2
# and the number of odd digits is :  3

# %%
num = eval(input("Enter a number : "))
cnum = num
revnum = 0
while num>0:
    rem = num%10
    revnum=revnum*10+rem
    num = num//10
if revnum==cnum:
    print("The number is palindrome...")
else:
    print("The number is not palindrome...")
# Out:
# The number is not palindrome...

# %%
username = "ritwik@"
password = "Kundu@123"
inuser = input("Enter your username : ")
inpass = input("Enter your password : ")
attemp = 1
flag = True
while attemp<=3:
    flag = True
    if(inuser != username):
        flag = False
    if inpass != password:
        flag = False
    if flag == False:
        attemp+=1
        print(attemp)
        inuser = input("Please enter correct username : ")
        inpass = input("Please enter correct password : ")
    else:
        flag = True
        break
if(flag == True):
    print("You are logging in...")
else:
    print("Sorry!!! try again later...")
# Out:
# Sorry!!! try again later...

# %%
num = eval(input("Enter the number : "))
digit = eval(input("Enter the digit : "))
count = 0
while num>0:
    rem = num%10
    if rem == digit:
        count+=1
    num = num//10
print("the digit comes ",count," times")
# Out:
# the digit comes  6  times

# %%
sum = eval(input("Enter a number : "))
while sum <100:
    num = eval(input("Enter another number : "))
    sum+=num
print("The sum is : ",sum)
# Out:
# The sum is :  102

# %%
print(range(5))
# Out:
# range(0, 5)

# %%
print(print("Hello"))
# Out:
# Hello
# None

# %%
def add():
    a = eval(input("Enter an integer : "))
    b = eval(input("Enter another one integer : "))
    return a+b

sum = add()
print(sum)
# Out:
# 35

# %%
def evenOddCount(num):
    even = 0
    odd = 0
    while num>0:
        rem = num%10
        if rem%2 == 0:
            even += 1
        else:
            odd += 1
        num = num//10
    return even, odd
num = eval(input("Enter a number : "))
even, odd = evenOddCount(num)
print("The number of even digits is : ",even)
print("and the number of odd digits is : ",odd)
# Out:
# The number of even digits is :  4
# and the number of odd digits is :  5

# %%
def ispalindrome(num):
    cnum = num
    revnum = 0
    while num>0:
        rem = num%10
        revnum=revnum*10+rem
        num = num//10
    if revnum==cnum:
        return True
    else:
        return False
num = eval(input("Enter a number : "))
ans = ispalindrome(num)
if ans:
    print("Palindrome")
else:
    print("not palindrome")
# Out:
# Palindrome

# %%
def greet(name = 'user', clg = 'hit'):
    print("Hello ",name)
    print("college ",clg)
greet(clg = 'haldia', name = 'ritwik')
# Out:
# Hello  ritwik
# college  haldia

# %%
def total(*n): #non keyword variavle length argument
    print(n)
    print(type(n))
    print("sum = ",sum(n))

total(12,23,34,45,56)
# Out:
# (12, 23, 34, 45, 56)
# <class 'tuple'>
# sum =  170

# %%
def details(**data): #keword variable length argument
    print(data)
details(name="Ritwik", age = 41, city = "Arambagh")
# Out:
# {'name': 'Ritwik', 'age': 41, 'city': 'Arambagh'}

# %%
a = 20
print(f"hello, :{20}")
# Out:
# hello, :20

# %% [markdown]
# ## for loop question

# %%
def cvowl(s:str) ->None:
    '''
    this function is use to count the number ov vowels present in a string...
    '''
    count = 0
    for i in s:
        if i in "aeiouAEIOU":
            count += 1
    print("count : ",count)
s = input("Enter a String : ")
cvowl(s)
# Out:
# count :  2

# %%
def freqChar(s:string) -> None:
    '''
    this function is use to print the frequency of each and every char in a string...
    '''
    for i in s:
        
s = input("Enter a string : ")

# %%
import logging

logging.basicConfig(
    filename="bank.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def count_vowels(s: str) -> int:
    """
    Count the number of vowels in a given string.
    Parameters:
        s (str): Input string
    Returns:
        int: Total number of vowels in the string.
    """
    logging.info("Counting vowels in the string")
    vowels = "aeiouAEIOU"
    count = 0
    for ch in s:
        if ch in vowels:
            count += 1

    logging.info(f"Vowel count calculated: {count}")
    return count

s = "programming"
result = count_vowels(s)
print("Vowel count:", result)
# Out:
# Vowel count: 3

# %%
import logging

logging.basicConfig(
    filename="frequency.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def frequency_char(s: str) -> dict:
    """
    Count the frequency of each character in a given string.
    Parameters:
        s (str): Input string
    Returns:
        dict: Character frequency dictionary
    """
    logging.info("Calculating frequency of characters in the string")

    freq = {}

    for ch in s:
        if ch in freq:
            freq[ch] += 1
        else:
            freq[ch] = 1

    logging.info(f"Character frequencies calculated: {freq}")
    return freq


s = "programming"
result = frequency_char(s)

print("Character frequencies:")
for char, count in result.items():
    print(char, ":", count)
# Out:
# Character frequencies:
# p : 1
# r : 2
# o : 1
# g : 2
# a : 1
# m : 2
# i : 1
# n : 1

# %%
import logging

logging.basicConfig(
    filename="frequency.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

def frequency_char(s: str) -> dict:
    """
    Count the frequency of each character in a given string.
    Parameters:
        s (str): Input string
    Returns:
        dict: Character frequency dictionary
    """
    logging.info("Calculating frequency of characters in the string")

    freq = {}

    for ch in s:
        if ch in freq:
            freq[ch] += 1
        else:
            freq[ch] = 1

    logging.info(f"Character frequencies calculated: {freq}")
    return freq


s = "programming"
result = frequency_char(s)

print("Character frequencies:")
for char, count in result.items():
    print(char, ":", count)

# %%
# backchodi start

# %%
li1 = [1,2,3,4,5,6,7,8]
li2= [1,2,3,4,6,8]
# print(li1 & li2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 li1 = [1,2,3,4,5,6,7,8]
#       2 li2= [1,2,3,4,6,8]
# ----> 3 print(li1 & li2)
#
# TypeError: unsupported operand type(s) for &: 'list' and 'list'

# %%
import re
s = "Python is very easy..."
# re.search("easy",s)
re.match("Python",s)
# Out:
# <re.Match object; span=(0, 6), match='Python'>

# %%
import re
m = re.search(r"\d+", "Age is 21") # m stores match details
m.group()
# Out:
# '21'

# %%
import re
m = re.search(r"(\d+)-(\d+)","2025-02")
m.groups()
# Out:
# ('2025', '02')
