# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("List of Countries by Sugarcane Production.csv")
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.drop(columns='Unnamed: 0', inplace=True)
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America       768.678.382                  3.668,531
# 1     India           Asia       348.448.000                     260721
# 2     China           Asia       123.059.739                      88287
# 3  Thailand           Asia        87.468.496                  1.264,303
# 4  Pakistan           Asia        65.450.704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     103 non-null    str
#  1   Continent                   103 non-null    str
#  2   Production (Tons)           103 non-null    str
#  3   Production per Person (Kg)  103 non-null    str
#  4   Acreage (Hectare)           102 non-null    str
#  5   Yield (Kg / Hectare)        102 non-null    str
# dtypes: str(6)
# memory usage: 5.0 KB

# %%
df['Production (Tons)'] = df['Production (Tons)'].str.replace('.','')
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                  3.668,531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                  1.264,303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace('.','')
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668,531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264,303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df['Production per Person (Kg)'] = df['Production per Person (Kg)'].str.replace(',','')
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                    3668531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                    1264303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0        10.226.205             75.167,5
# 1         4.950.000             70.393,5
# 2         1.675.215             73.459,1
# 3         1.336.575             65.442,2
# 4         1.130.820               57.879

# %%
df['Acreage (Hectare)'] = df['Acreage (Hectare)'].str.replace('.','')
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                    3668531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                    1264303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205             75.167,5
# 1           4950000             70.393,5
# 2           1675215             73.459,1
# 3           1336575             65.442,2
# 4           1130820               57.879

# %%
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].str.replace('.','')
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                    3668531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                    1264303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167,5
# 1           4950000              70393,5
# 2           1675215              73459,1
# 3           1336575              65442,2
# 4           1130820                57879

# %%
df['Yield (Kg / Hectare)'] = df['Yield (Kg / Hectare)'].str.replace(',','')
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                    3668531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                    1264303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205               751675
# 1           4950000               703935
# 2           1675215               734591
# 3           1336575               654422
# 4           1130820                57879

# %%
df.rename(
    columns={
        'Production (Tons)': 'Production_Tons',
        'Production per Person (Kg)' : 'Production_per_Person_Kg',
        'Acreage (Hectare)': 'Acreage_Hectare',
        'Yield (Kg / Hectare)' : 'Yield_Kg/Hectare'
    },
    inplace=True
)
df.head()
# Out:
#     Country      Continent Production_Tons Production_per_Person_Kg  \
# 0    Brazil  South America       768678382                  3668531
# 1     India           Asia       348448000                   260721
# 2     China           Asia       123059739                    88287
# 3  Thailand           Asia        87468496                  1264303
# 4  Pakistan           Asia        65450704                   324219
#
#   Acreage_Hectare Yield_Kg/Hectare
# 0        10226205           751675
# 1         4950000           703935
# 2         1675215           734591
# 3         1336575           654422
# 4         1130820            57879

# %%
df.isnull().sum()
# Out:
# Country                     0
# Continent                   0
# Production_Tons             0
# Production_per_Person_Kg    0
# Acreage_Hectare             1
# Yield_Kg/Hectare            1
# dtype: int64

# %%
df[df.Acreage_Hectare.isnull()]
# Out:
#      Country Continent Production_Tons Production_per_Person_Kg  \
# 99  Djibouti    Africa              53                       51
#
#    Acreage_Hectare Yield_Kg/Hectare
# 99             NaN              NaN

# %%
df.dropna(inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(1000)
# Out:
#        Country      Continent Production_Tons Production_per_Person_Kg  \
# 0       Brazil  South America       768678382                  3668531
# 1        India           Asia       348448000                   260721
# 2        China           Asia       123059739                    88287
# 3     Thailand           Asia        87468496                  1264303
# 4     Pakistan           Asia        65450704                   324219
# ..         ...            ...             ...                      ...
# 97       Spain         Europe             394                        8
# 98     Lebanon           Asia              97                       16
# 99   Singapore           Asia              50                        9
# 100      Samoa        Oceania              12                        6
# 101      Syria           Asia               1                        0
#
#     Acreage_Hectare Yield_Kg/Hectare
# 0          10226205           751675
# 1           4950000           703935
# 2           1675215           734591
# 3           1336575           654422
# 4           1130820            57879
# ..              ...              ...
# 97                9           435965
# 98                3           283864
# 99                2               25
# 100               1           119498
# 101               0           830342
#
# [102 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   102 non-null    str
#  1   Continent                 102 non-null    str
#  2   Production_Tons           102 non-null    str
#  3   Production_per_Person_Kg  102 non-null    str
#  4   Acreage_Hectare           102 non-null    str
#  5   Yield_Kg/Hectare          102 non-null    str
# dtypes: str(6)
# memory usage: 4.9 KB

# %%
df.columns
# Out:
# Index(['Country', 'Continent', 'Production_Tons', 'Production_per_Person_Kg',
#        'Acreage_Hectare', 'Yield_Kg/Hectare'],
#       dtype='str')

# %%
df.columns[2:]
# Out:
# Index(['Production_Tons', 'Production_per_Person_Kg', 'Acreage_Hectare',
#        'Yield_Kg/Hectare'],
#       dtype='str')

# %%
for i in df.columns[2:]:
    df[i] = df[i].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   102 non-null    str
#  1   Continent                 102 non-null    str
#  2   Production_Tons           102 non-null    float64
#  3   Production_per_Person_Kg  102 non-null    float64
#  4   Acreage_Hectare           102 non-null    float64
#  5   Yield_Kg/Hectare          102 non-null    float64
# dtypes: float64(4), str(2)
# memory usage: 4.9 KB

# %%
df.head()
# Out:
#     Country      Continent  Production_Tons  Production_per_Person_Kg  \
# 0    Brazil  South America      768678382.0                 3668531.0
# 1     India           Asia      348448000.0                  260721.0
# 2     China           Asia      123059739.0                   88287.0
# 3  Thailand           Asia       87468496.0                 1264303.0
# 4  Pakistan           Asia       65450704.0                  324219.0
#
#    Acreage_Hectare  Yield_Kg/Hectare
# 0       10226205.0          751675.0
# 1        4950000.0          703935.0
# 2        1675215.0          734591.0
# 3        1336575.0          654422.0
# 4        1130820.0           57879.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique().sum()
# Out:
# np.int64(514)

# %%
#How many contries Produce sugercane from each continent?
cont = df.Continent.value_counts()
cont
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title("Top Sugarcane Production Countires")
plt.bar(cont.keys(), cont)
plt.show()

# %%
#Which country produce maximum sugarcane ?
